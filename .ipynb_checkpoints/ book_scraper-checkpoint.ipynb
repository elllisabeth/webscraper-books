# %% [markdown]
# ## Install Dependencies

# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bs - fanny elisabeth\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Import Libraries

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %% [markdown]
# ## Create Scraper Function

# %%
def scrape_books():
    url = "https://books.toscrape.com/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    book_list = []
    books = soup.find_all("article", class_="product_pod")

    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        rating = book.p["class"][1]
        stock = book.find("p", class_="instock availability").text.strip()
        image_url = "https://books.toscrape.com/" + book.img["src"]

        book_list.append({
            "title": title,
            "price": price,
            "rating": rating,
            "stock": stock,
            "image_url": image_url
        })
    
    return book_list

# %% [markdown]
# ## Create Scraper Function

# %%
books = scrape_books()
books[:5]  # show sample
# Out:
# [{'title': 'A Light in the Attic',
#   'price': 'Â£51.77',
#   'rating': 'Three',
#   'stock': 'In stock',
#   'image_url': 'https://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg'},
#  {'title': 'Tipping the Velvet',
#   'price': 'Â£53.74',
#   'rating': 'One',
#   'stock': 'In stock',
#   'image_url': 'https://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg'},
#  {'title': 'Soumission',
#   'price': 'Â£50.10',
#   'rating': 'One',
#   'stock': 'In stock',
#   'image_url': 'https://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg'},
#  {'title': 'Sharp Objects',
#   'price': 'Â£47.82',
#   'rating': 'Four',
#   'stock': 'In stock',
#   'image_url': 'https://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg'},
#  {'title': 'Sapiens: A Brief History of Humankind',
#   'price': 'Â£54.23',
#   'rating': 'Five',
#   'stock': 'In stock',
#   'image_url': 'https://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg'}]

# %% [markdown]
# ## Convert to DataFrame

# %%
df = pd.DataFrame(books)
df
# Out:
#                                                 title    price rating  \
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60   Four
# 9                                     The Black Maria  Â£52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99    Two
# 11                              Shakespeare's Sonnets  Â£20.66   Four
# 12                                        Set Me Free  Â£17.46   Five
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29   Five
# 14                          Rip it Up and Start Again  Â£35.02   Five
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25  Three
# 16                                               Olio  Â£23.88    One
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59    One
# 18                       Libertarianism for Beginners  Â£51.33    Two
# 19                            It's Only the Himalayas  Â£45.17    Two
#
#        stock                                          image_url
# 0   In stock  https://books.toscrape.com/media/cache/2c/da/2...
# 1   In stock  https://books.toscrape.com/media/cache/26/0c/2...
# 2   In stock  https://books.toscrape.com/media/cache/3e/ef/3...
# 3   In stock  https://books.toscrape.com/media/cache/32/51/3...
# 4   In stock  https://books.toscrape.com/media/cache/be/a5/b...
# 5   In stock  https://books.toscrape.com/media/cache/68/33/6...
# 6   In stock  https://books.toscrape.com/media/cache/92/27/9...
# 7   In stock  https://books.toscrape.com/media/cache/3d/54/3...
# 8   In stock  https://books.toscrape.com/media/cache/66/88/6...
# 9   In stock  https://books.toscrape.com/media/cache/58/46/5...
# 10  In stock  https://books.toscrape.com/media/cache/be/f4/b...
# 11  In stock  https://books.toscrape.com/media/cache/10/48/1...
# 12  In stock  https://books.toscrape.com/media/cache/5b/88/5...
# 13  In stock  https://books.toscrape.com/media/cache/94/b1/9...
# 14  In stock  https://books.toscrape.com/media/cache/81/c4/8...
# 15  In stock  https://books.toscrape.com/media/cache/54/60/5...
# 16  In stock  https://books.toscrape.com/media/cache/55/33/5...
# 17  In stock  https://books.toscrape.com/media/cache/09/a3/0...
# 18  In stock  https://books.toscrape.com/media/cache/0b/bc/0...
# 19  In stock  https://books.toscrape.com/media/cache/27/a5/2...

# %% [markdown]
# ## Save to JSON

# %%
with open("books.json", "w") as f:
    json.dump(books, f, indent=4)

"books.json saved successfully!"
# Out:
# 'books.json saved successfully!'
